# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import timedelta
import numpy as np
from pprint import pprint

# %%
str_filename = '../dune_artblocks_mints.csv'

# %%
fh = open(str_filename)
csv_reader = csv.reader(fh)

# %%
csv_reader = csv.reader(fh)
csv_header = next(csv_reader)

# %%
fh.close()

# %%
df_temp = pd.read_csv(str_filename, header=None, skiprows=1, names=csv_header)
i = 0
for row in df_temp['time']:
    row = row.replace('+00:00', '')
    row = row.replace('T', ' ')
    df_temp.at[i, 'time'] = row
    i += 1
df_temp
# Out:
#                       time                  name  eth_total  usd_total  \
# 0      2022-08-09 21:30:26  Gels by Jason Brown        0.15   256.4190
# 1      2022-08-09 21:27:20  THE SOURCE CoDE by O       0.20   341.8920
# 2      2022-08-09 21:24:21  Facets by conundrume       0.10   170.6110
# 3      2022-08-09 21:01:56       Swing by Eltono       0.15   255.0600
# 4      2022-08-09 17:07:06      8 by Bård Ionson       0.18   304.5492
# ...                    ...                   ...        ...        ...
# 44890  2022-01-01 03:26:49  Dream Engine by REMO       0.10   373.1310
# 44891  2022-01-01 02:50:44     Freehand by WAWAA       0.12   447.8640
# 44892  2022-01-01 01:11:00  CryptoNewYorker by Q       0.00     0.0000
# 44893  2022-01-01 00:58:00  Attraction by Jos Vr       0.15   558.3630
# 44894  2022-01-01 00:09:23  CryptoNewYorker by Q       0.00     0.0000
#
#        refund_eth  refund_usd   gas_eth project_type  projectid    tokenid  \
# 0             0.0         0.0  0.000209      Factory        322  322000132
# 1             0.0         0.0  0.000153      Factory        187  187000165
# 2             0.0         0.0  0.000153      Factory        249  249000222
# 3             0.0         0.0  0.000207      Factory        184  184000249
# 4             0.0         0.0  0.000159      Factory        179  179000105
# ...           ...         ...       ...          ...        ...        ...
# 44890         0.0         0.0  0.014069      Factory        223  223000265
# 44891         0.0         0.0  0.014876      Factory        211  211000164
# 44892         0.0         0.0  0.021243      Factory        189  189000984
# 44893         0.0         0.0  0.013791      Factory        229  229000312
# 44894         0.0         0.0  0.019833      Factory        189  189000983
#
#                                                  tx_hash  mint_count
# 0      \x657b0e82d8e891d414e853f70eedb9a3d585b6db2b4f...           1
# 1      \xc2b38ee0431f08dfbf60c9a371eb2759af769b17b463...           1
# 2      \x5e954524f1505cb1a71cfd6580bf7d9a248e885b6b57...           1
# 3      \x10e9f2c68f9254fa1e394b0dc98bd30c34a0ad0ba81b...           1
# 4      \x24a35c0cbcf342fbeded159696463339b578b65fe535...           1
# ...                                                  ...         ...
# 44890  \xbdc649a4b50067b30675568bd5337b0c1356c3c019c9...           1
# 44891  \xf379b87e7bd9d8214790fc17e564cf545aff708f71e6...           1
# 44892  \xd50846180a99ba101219e33d4eb2b425d0bcf5530994...           1
# 44893  \x68d37300a53c2d1f7c683af5bb87010bde0a0027f1ad...           1
# 44894  \x7220fbc967477c658e4e53db2f51afa01687b5f7015a...           1
#
# [44895 rows x 12 columns]

# %%
df_sig = df_temp.loc[(df_temp['project_type'] == 'Curated')]
df_sig['eth_total']
# Out:
# 4744     3.000000
# 4745     2.858306
# 4746     2.858306
# 4747     2.868078
# 4748     2.809446
#            ...
# 44479         NaN
# 44480         NaN
# 44481         NaN
# 44482         NaN
# 44483         NaN
# Name: eth_total, Length: 12750, dtype: float64

# %%
#df_sig = df_sig.set_index('projectid')
df_sig = df_sig.loc[(df_sig['eth_total'] > 0)]
df_sig2 = df_sig.groupby('projectid').min().reset_index()
df_mean = df_sig.groupby('projectid').mean().reset_index()
df_median = df_sig.groupby('projectid').median().reset_index()
df_sig2['eth_min'] = df_min['eth_total']
df_sig2['eth_mean'] = df_mean['eth_total']
df_sig2['eth_median'] = df_median['eth_total']
df_sig2
# Out:
#     projectid                 time                  name  eth_total  \
# 0         233  2022-01-10 18:00:19      Chimera by mpkoz   2.400000
# 1         250  2022-01-24 18:00:57  Cosmic Reef by Leo V   0.400000
# 2         255  2022-01-31 18:00:27  Screens by Thomas Li   1.250000
# 3         261  2022-02-07 18:16:55  Para Bellum  by Matt   0.100000
# 4         267  2022-02-14 18:13:03  entretiempos by Marc   0.200000
# 5         282  2022-03-21 17:10:53  Memories of Qilin by   0.750000
# 6         283  2022-04-14 20:30:44  OnChainChain by Rizz   0.025000
# 7         284  2022-03-29 17:29:45  Ancient Courses of F   0.300000
# 8         296  2022-04-18 17:19:40    Flux by Owen Moore   0.200000
# 9         304  2022-04-29 16:59:53  Anticyclone by Willi   0.750000
# 10        309  2022-05-25 17:00:26  Colorspace by Tabor    0.280012
# 11        320  2022-06-08 17:00:14  montreal friend scal   0.226588
# 12        328  2022-06-29 17:12:04  Sudfah by Melissa Wi   0.918889
# 13        334  2022-07-13 17:00:17  Running Moon by Lici   2.809446
#
#       usd_total  refund_eth  refund_usd   gas_eth project_type    tokenid  \
# 0   7242.624000    0.000000    0.000000  0.009990      Curated  233000001
# 1    945.500000    0.000000    0.000000  0.010394      Curated  250000001
# 2   3349.500000    0.000000    0.000000  0.010727      Curated  255000001
# 3    316.996000    0.000000    0.000000  0.010025      Curated  261000001
# 4    584.022000    0.000000    0.000000  0.008426      Curated  267000001
# 5   2184.375000    0.000000    0.000000  0.009008      Curated  282000001
# 6     75.410000    0.000000    0.000000  0.009361      Curated  283000001
# 7   1019.811000    0.000000    0.000000  0.009008      Curated  284000001
# 8    594.342000    0.000000    0.000000  0.011483      Curated  296000001
# 9   2126.055000    0.000000    0.000000  0.010663      Curated  304000001
# 10   496.514243    0.027303   53.644943  0.000078      Curated  309000001
# 11   367.951342    0.022476   40.516485  0.000023      Curated  320000001
# 12   903.602008    0.089111   97.254084  0.000145      Curated  328000001
# 13  2744.182007    0.274104  297.427764  0.000067      Curated  334000001
#
#                                               tx_hash  mint_count   eth_min  \
# 0   \x000637f220fa85a957dd8a63dc020f59bfcf18384164...           1  2.400000
# 1   \x000c3b6983b6a4338412a018b28dd4b403105db96abe...           1  0.400000
# 2   \x006800d70b969bafa4f45bba989ab065e0034dc39e37...           1  1.250000
# 3   \x00415d19d8d73996712d13528f4027b882c02b4a9a29...           1  0.100000
# 4   \x00a3d3050a0d2647bb99632fb80054bc18cdb1dfdab4...           1  0.200000
# 5   \x00085a2b4b94a920d81c0f56287db3b1e9c501035ea1...           1  0.750000
# 6   \x001776d5a5ddd88f2ee3be1bfb9af6c9a176c4180e35...           1  0.025000
# 7   \x00f3b460dec2217293e57d2397999634fd9f981f2d85...           1  0.300000
# 8   \x001a3bc190ff254b4d01dd402abd2c956b5c3be962a6...           1  0.200000
# 9   \x0011d4b36a3e10dd2e9b61184f0b72ee78284f43cb7b...           1  0.750000
# 10  \x008bffeb23b11c3a481dd4e7ed609c42f10f11313503...           1  0.280012
# 11  \x003326c53ff5fb87a599d552fd56217fe0de62e9c63f...           1  0.226588
# 12  \x011cca29a5437871f072d40d2c5237a03a8a2649a071...           1  0.918889
# 13  \x009767f7a75672b376956d395b6dde4e5311aa3de595...           1  2.809446
#
#     eth_mean  eth_median
# 0   2.495740    2.400000
# 1   0.752297    0.600000
# 2   1.459459    1.500000
# 3   0.167768    0.200000
# 4   0.252092    0.200000
# 5   0.803763    0.750000
# 6   0.030178    0.025000
# 7   0.309159    0.300000
# 8   0.209419    0.200000
# 9   0.899249    1.000000
# 10  0.411525    0.298019
# 11  0.280019    0.256718
# 12  0.989074    0.960556
# 13  2.926206    2.918567

# %%
plt.rcParams["figure.figsize"] = (20,5)
x = df_sig2['projectid']
y = df_sig2['eth_total']
y2 = df_sig2['eth_mean']
y3 = df_sig2['eth_median']
plt.scatter(x, y ,c='blue')
plt.scatter(x, y2, c='green')
plt.scatter(x, y3, c='red')
ax = plt.gca()
for i, txt in enumerate(df_sig2.projectid):
   ax.annotate(txt, (df_sig2.projectid.iat[i]+0.05, df_sig2.eth_min.iat[i]))
plt.xlabel("Collection Id")
plt.ylabel("Price(eth)")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
